# %% [markdown]
# # Wiki - Markdown Parser
#
# Parses the markdown files located in `assets/data/wiki/original` and outputs the parsed files to `assets/data/wiki/converted` as JSON files, so that they can be used in the frontend.
#
#
# #### Just some printing utilities

# %%
# prints in orange color
def print_warn(obj):
    print(f"\033[93m{obj}\033[0m")

# prints in green color
def print_success(obj):
    print(f"\033[92m{obj}\033[0m")

# %% [markdown]
# ## Load the markdown files
#
# Also parses the title from the markdown file
#
# This expects a markdown H1 title at the top of the file
#
# ```md
# # Title
# ```

# %%
import json
import os

markdownFilesPath = "./original"

# load all the markdown files (recursively) in this directory into a dictionary with the filename (without extension) as the key

validLanguages = ["en", "de"]

markdownFiles = []

for root, dirs, files in os.walk(markdownFilesPath):
    for file in files:
        if file.endswith(".md"):
            fileKey = os.path.splitext(os.path.join(root,file))[0].split("\\")[1:]
            fileKey = "/".join(fileKey)
            print(f"Found markdown file: {fileKey}")

            language = fileKey.split("/")[1]

            if language not in validLanguages:
                print_warn(f"\t⚠️ Warning: Language '{language}' is not valid. Skipping file {fileKey}")
                continue

            print_success(f"\t✅ Language: {language}")
            
            with open(os.path.join(root, file), "r", encoding="utf-8") as f:
                markdownContent = f.read()

                # find first line containing a # and use it as the title
                title = None
                for line in markdownContent.splitlines():
                    if line.startswith("# "):
                        title = line[2:]  # Remove the "# " to get the title text
                        break

                if title:
                    print_success(f"\t✅ Title: {title}")
                else:
                    print_warn(f"\t⚠️ Warning: Title is missing in the markdown file {fileKey}")

                markdownFiles.append({
                    "slug": fileKey,
                    "content": markdownContent,
                    "title": title if title else "Untitled",
                    "language": language
                })
# Out:
# Found markdown file: App-Wiki-Articles/de/Fokus-halten
# 	✅ Language: de
# 	✅ Title: Fokus halten
# Found markdown file: App-Wiki-Articles/de/Lernmethoden
# 	✅ Language: de
# 	✅ Title: Lernmethoden
# Found markdown file: App-Wiki-Articles/de/Lernraum-und-Lernumgebung
# 	✅ Language: de
# 	✅ Title: Lernraum und Lernumgebung
# Found markdown file: App-Wiki-Articles/de/Lerntyp-Test-Hinweise
# 	✅ Language: de
# 	✅ Title: Hinweise zu deinem Ergebnis des  Lerntyp Tests
# Found markdown file: App-Wiki-Articles/de/Lerntypen
# 	✅ Language: de
# 	✅ Title: Lerntypen
# Found markdown file: App-Wiki-Articles/de/Lernübersichten
# 	✅ Language: de
# 	⚠️ Warning: Title is missing in the markdown file App-Wiki-Articles/de/Lernübersichten
# Found markdown file: App-Wiki-Articles/de/Prüfungsangst
# 	✅ Language: de
# 	✅ Title: Wie geht man mit Prüfungsangst um?
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Aktives-Lesen
# 	✅ Language: de
# 	✅ Title: Aktives Lesen
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Forschendes-Lernen
# 	✅ Language: de
# 	✅ Title: Forschendes Lernen
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Fragen-Stellen
# 	✅ Language: de
# 	✅ Title: Richtig Fragen Stellen
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Gamification
# 	✅ Language: de
# 	✅ Title: Was ist Gamification?
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Gedächtnispalast
# 	✅ Language: de
# 	✅ Title: Der Gedächtnispalast
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/In-Gruppen-Lernen
# 	✅ Language: de
# 	✅ Title: In Gruppen Lernen
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Lernen-durch-Lehren
# 	✅ Language: de
# 	✅ Title: Durchführung
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Lernmethoden-Anwenden
# 	✅ Language: de
# 	✅ Title: Wann verwende ich die Lernmethoden?
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Memory-Methode
# 	✅ Language: de
# 	✅ Title: Memory-Methode
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Methoden-des-Aktiven-Lesens
# 	✅ Language: de
# 	✅ Title: Die PQ4R-Methode
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Mnemotechniken
# 	✅ Language: de
# 	✅ Title: Mnemotechniken
# Found markdown file: App-Wiki-Articles/de/Lernmethoden/Modell-lernen
# 	✅ Language: de
# 	✅ Title: Phasen des Modell lernen
# Found markdown file: App-Wiki-Articles/de/Lerntypen/Auditiver-Lerntyp
# 	✅ Language: de
# 	✅ Title: Auditiver Lerntyp
# Found markdown file: App-Wiki-Articles/de/Lerntypen/Kinästhetischer-Lerntyp
# 	✅ Language: de
# 	✅ Title: Kinästhetischer Lerntyp
# Found markdown file: App-Wiki-Articles/de/Lerntypen/Lesender-Lerntyp
# 	✅ Language: de
# 	✅ Title: Lesender/Schreibender Lerntyp
# Found markdown file: App-Wiki-Articles/de/Lerntypen/Visueller-Lerntyp
# 	✅ Language: de
# 	✅ Title: Visueller Lerntyp
# Found markdown file: App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Emotionale-Ebene
# 	✅ Language: de
# 	✅ Title: Prüfungsangst auf emotionaler Ebene
# Found markdown file: App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Kognitive-Ebene
# 	✅ Language: de
# 	✅ Title: Prüfungsangst auf Kognitiver Ebene
# Found markdown file: App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Körperliche-Ebene
# 	✅ Language: de
# 	✅ Title: Prüfungsangst auf der körperlichen Ebene
# Found markdown file: App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Verhaltensebene
# 	✅ Language: de
# 	✅ Title: Prüfungsangst auf der Verhaltensebene
# Found markdown file: App-Wiki-Articles/en/Exam-Anxiety
# 	✅ Language: en
# 	✅ Title: Exam Anxiety
# Found markdown file: App-Wiki-Articles/en/Focus
# 	✅ Language: en
# 	✅ Title: Focus
# Found markdown file: App-Wiki-Articles/en/Mental-Health
# 	✅ Language: en
# 	✅ Title: Mental Health
# Found markdown file: App-Wiki-Articles/en/Physical-Health
# 	✅ Language: en
# 	✅ Title: Physical Health
# Found markdown file: App-Wiki-Articles/en/Resilience
# 	✅ Language: en
# 	✅ Title: Resilience
# Found markdown file: App-Wiki-Articles/en/Sleep
# 	✅ Language: en
# 	✅ Title: Sleep
# Found markdown file: App-Wiki-Articles/en/Stress-Management
# 	✅ Language: en
# 	✅ Title: Stress Management
# Found markdown file: App-Wiki-Articles/en/Time-Management
# 	✅ Language: en
# 	✅ Title: Time Management

# %% [markdown]
# ## Loads the slug to UUID mapping
#
# The mapping is stored in uuids.json and ensures that the UUIDs are consistent
#
# Also, if an article has no associated UUID, it will be discarded. This way, no orphaned articles will be present in the final data.

# %%
uuids = []

with open("uuids.json",encoding="utf-8") as uuidFile: 

    uuids = json.load(uuidFile)

if len(set(uuids.values())) != len(uuids.values()):
        print_warn("⚠️ WARNING: UUIDS contain duplicates")

else:
    print_success("✅ UUIDs successfully loaded")
# Out:
# ✅ UUIDs successfully loaded

# %% [markdown]
# ## Map the UUIDs to the articles and replace Markdown Links with UUIDs
#
#
# - Prints warnings for any links that are not found.
# - Also parses the keywords from the markdown file from a html comment at the top of the file
#
# ```md
# <!-- ["keyword1", "keyword2"] -->
# ```
# - Prints warnings if no keywords for an article are found

# %%
import re

articles = []

for markdownFile in markdownFiles:
    slug = markdownFile['slug']
    content = markdownFile['content']
    title = markdownFile['title']
    language = markdownFile['language']

    # ignore pages that don't have an associated uuid in uuids.json
    if slug not in uuids:
        print_warn(f"\n⚠️ WARNING: MISSING UUID FOR {title}\n{slug}")
        continue
            
    uuid = uuids[slug]
    keywords = []

    print_success(f"\n✅ Found Entry {title}")
    print(f"\t[{slug}]({uuid})")

    # look for <!-- ["keyword1","keyword2"] --> and parse the list 
    keyword_comment_match = re.search(r'<!-- (\[.*?\]) -->',content)

    if keyword_comment_match:
        keyword_json = json.loads(keyword_comment_match.group(1))
        for keyword in keyword_json:
            keywords.append(keyword)
        print_success(f"\t✅ Found Keywords {keywords}")
    else:
        print_warn(f"\t⚠️ WARNING: MISSING KEYWORDS FOR {title}\n\t\t{slug}")

    # * replace links [Text](slug) with links [Text](uuid) to uuids
    for slug_, id_ in uuids.items():
        content = content.replace(f"({slug_})",f"({id_})")

    # * Find Markdown Links that have not yet been replaced with a Link to a UUID indicating an unresolved Link or typo in the path
    nonUUIDLink_matches = re.findall(r"\[(.*?)\]\((?!([0-9a-fA-F]{8}-[0-9a-fA-F]{4}-4[0-9a-fA-F]{3}-[89aAbB][0-9a-fA-F]{3}-[0-9a-fA-F]{12}))([^)]*)\)",content);

    for nonUUIDLink in nonUUIDLink_matches:
        print_warn(f"\t⚠️ WARNING: Found unresolved link {nonUUIDLink[0]} {nonUUIDLink[2]}")

    # add spaces between words "KörperlicheEbene" -> "Körperliche Ebene"
    if " " not in title:
        title = " ".join(re.findall('[A-Z][^A-Z]*', title))

    related_wikis = []
    online_resources = []

    articles.append({
        "id":uuid,
        "title":title,
        "slug":slug,
        "keywords":keywords,
        "markdown_content":content,
        "related_wikis":related_wikis,
        "online_resources":online_resources,
        "language":language,
    })

# print the articles as json
#print(json.dumps(articles, indent=4, ensure_ascii=False))


print_success(f"Found {len(articles)} articles")
# Out:
# ✅ Found Entry Fokus halten
# 	[App-Wiki-Articles/de/Fokus-halten](cc779f27-e1d4-48ab-b75a-2b7daaa67e50)
# 	✅ Found Keywords ['Fokus halten', 'Lernmethoden']
#
# ✅ Found Entry Lernmethoden
# 	[App-Wiki-Articles/de/Lernmethoden](3a7372e1-943b-4de3-a700-bcf37043fffa)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Lernraum und Lernumgebung
# 	[App-Wiki-Articles/de/Lernraum-und-Lernumgebung](9f07c546-657d-4bad-bd9a-7e847c4496d9)
# 	✅ Found Keywords ['Lernraum und Lernumgebung ', 'Lerntypen']
#
# ✅ Found Entry Hinweise zu deinem Ergebnis des  Lerntyp Tests
# 	[App-Wiki-Articles/de/Lerntyp-Test-Hinweise](599b335c-bdbd-4af9-91f4-a37d5fe7dcfe)
# 	✅ Found Keywords ['Lerntypen']
#
# ✅ Found Entry Lerntypen
# 	[App-Wiki-Articles/de/Lerntypen](662d5bbf-48b1-4e55-92b7-fbb98f26d609)
# 	✅ Found Keywords ['Lernen', 'Lerntypen']
#
# ⚠️ WARNING: MISSING UUID FOR Untitled
# App-Wiki-Articles/de/Lernübersichten
#
# ✅ Found Entry Wie geht man mit Prüfungsangst um?
# 	[App-Wiki-Articles/de/Prüfungsangst](789f962a-89d7-40da-8508-54eb00fd86f7)
# 	✅ Found Keywords ['Prüfungsangst']
#
# ✅ Found Entry Aktives Lesen
# 	[App-Wiki-Articles/de/Lernmethoden/Aktives-Lesen](85a46ed6-3a01-4850-af53-6369da348914)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Forschendes Lernen
# 	[App-Wiki-Articles/de/Lernmethoden/Forschendes-Lernen](8fbc59cd-554f-4a06-a8b2-5cd88a949f2b)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Richtig Fragen Stellen
# 	[App-Wiki-Articles/de/Lernmethoden/Fragen-Stellen](d54d50b7-0722-4979-94b1-0354e5bd183a)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Was ist Gamification?
# 	[App-Wiki-Articles/de/Lernmethoden/Gamification](e843794e-8bd9-4e1c-b682-de4bfe8868e9)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Der Gedächtnispalast
# 	[App-Wiki-Articles/de/Lernmethoden/Gedächtnispalast](91d603a1-6412-4df6-8d85-63abd273d871)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry In Gruppen Lernen
# 	[App-Wiki-Articles/de/Lernmethoden/In-Gruppen-Lernen](4d6119f9-4f6d-4f8e-9db3-e3e539a9ca26)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Durchführung
# 	[App-Wiki-Articles/de/Lernmethoden/Lernen-durch-Lehren](1d6b94a1-6d9b-41ec-b918-8d9395379858)
# 	✅ Found Keywords ['Lehren', 'Lernen', 'Lernmethoden']
#
# ✅ Found Entry Wann verwende ich die Lernmethoden?
# 	[App-Wiki-Articles/de/Lernmethoden/Lernmethoden-Anwenden](d743a23a-ca03-4b31-b0f3-318e12f76752)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Memory-Methode
# 	[App-Wiki-Articles/de/Lernmethoden/Memory-Methode](6cb7f775-2b32-435d-9d9a-c8598850af7e)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden', 'Gedächtnis']
#
# ✅ Found Entry Die PQ4R-Methode
# 	[App-Wiki-Articles/de/Lernmethoden/Methoden-des-Aktiven-Lesens](d058c5c5-195f-4e49-bb2d-d9c7567c0f49)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Mnemotechniken
# 	[App-Wiki-Articles/de/Lernmethoden/Mnemotechniken](c37bf6fe-5a8f-4f8d-b586-06be1e33869c)
# 	✅ Found Keywords ['Erinnerung', 'Lernmethoden', 'Lernen']
#
# ✅ Found Entry Phasen des Modell lernen
# 	[App-Wiki-Articles/de/Lernmethoden/Modell-lernen](a8fa179f-b066-4629-b1f3-c5a3388448aa)
# 	✅ Found Keywords ['Lernen', 'Lernmethoden']
#
# ✅ Found Entry Auditiver Lerntyp
# 	[App-Wiki-Articles/de/Lerntypen/Auditiver-Lerntyp](a4dd98b7-9374-404b-8bda-bf7e3770007a)
# 	✅ Found Keywords ['Lernen', 'Lerntypen']
#
# ✅ Found Entry Kinästhetischer Lerntyp
# 	[App-Wiki-Articles/de/Lerntypen/Kinästhetischer-Lerntyp](8c4f0e74-cdc7-4cea-9638-b51d8699d27f)
# 	✅ Found Keywords ['Lernen', 'Lerntypen']
#
# ✅ Found Entry Lesender/Schreibender Lerntyp
# 	[App-Wiki-Articles/de/Lerntypen/Lesender-Lerntyp](bd37dd28-aac5-4548-aebb-1a242fca0928)
# 	✅ Found Keywords ['Lernen', 'Lerntypen']
#
# ✅ Found Entry Visueller Lerntyp
# 	[App-Wiki-Articles/de/Lerntypen/Visueller-Lerntyp](e84df49f-9d7a-4e42-8472-334a05af64a1)
# 	✅ Found Keywords ['Lernen', 'Lerntypen']
#
# ✅ Found Entry Prüfungsangst auf emotionaler Ebene
# 	[App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Emotionale-Ebene](8718b0bf-97f9-41dd-8b73-804de6dbb519)
# 	✅ Found Keywords ['Prüfungsangst']
#
# ✅ Found Entry Prüfungsangst auf Kognitiver Ebene
# 	[App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Kognitive-Ebene](f1412197-66a9-4f1a-8342-0540927d1b30)
# 	✅ Found Keywords ['Prüfungsangst']
#
# ✅ Found Entry Prüfungsangst auf der körperlichen Ebene
# 	[App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Körperliche-Ebene](490f580f-fc52-4a1d-a3bf-ec296f0a6f83)
# 	✅ Found Keywords ['Prüfungsangst']
#
# ✅ Found Entry Prüfungsangst auf der Verhaltensebene
# 	[App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Verhaltensebene](0eddc060-b2b2-444a-b8ab-5fedada8b1af)
# 	✅ Found Keywords ['Prüfungsangst']
#
# ✅ Found Entry Exam Anxiety
# 	[App-Wiki-Articles/en/Exam-Anxiety](55c654cd-0b7c-4c56-8587-afd2e30613f5)
# 	✅ Found Keywords ['Mental Health', 'Exams']
#
# ✅ Found Entry Focus
# 	[App-Wiki-Articles/en/Focus](a7e9d6cf-dc2d-45f5-ad40-670a1397fa6a)
# 	✅ Found Keywords ['Performance', 'Wellbeing', 'Mental Health']
#
# ✅ Found Entry Mental Health
# 	[App-Wiki-Articles/en/Mental-Health](1e6cd26e-b9d1-45b7-a465-4024bcfe1d84)
# 	✅ Found Keywords ['Mental Health', 'Stay Focused', 'Wellbeing']
#
# ✅ Found Entry Physical Health
# 	[App-Wiki-Articles/en/Physical-Health](1361fd13-9d9d-45be-87f7-27279cdaa72b)
# 	✅ Found Keywords ['Health', 'Wellbeing', 'Confidence']
#
# ✅ Found Entry Resilience
# 	[App-Wiki-Articles/en/Resilience](41a1de37-2671-42a9-b5f7-6eeaad731341)
# 	✅ Found Keywords ['Mental Health', 'Wellbeing', 'Confidence', 'Stress-Management']
#
# ✅ Found Entry Sleep
# 	[App-Wiki-Articles/en/Sleep](0d649c3c-ae1c-4369-9222-990f780f9eec)
# 	✅ Found Keywords ['Mental Health', 'Physical Health', 'Wellbeing']
#
# ✅ Found Entry Stress Management
# 	[App-Wiki-Articles/en/Stress-Management](026737e7-bb84-4f61-a8c2-4b63de6d65ce)
# 	✅ Found Keywords ['Wellbeing', 'Confidence', 'Mental Health', 'Physical Health']
#
# ✅ Found Entry Time Management
# 	[App-Wiki-Articles/en/Time-Management](3a851d11-43bf-4025-85f4-6323bf9bc858)
# 	✅ Found Keywords ['Performance', 'Wellbeing', 'Stress']
# Found 34 articles

# %% [markdown]
# ## Export the data to JSON

# %%
export_folder_path = "./converted/"

# create the export directory if it doesn't exist
if not os.path.exists(export_folder_path):
        os.makedirs(export_folder_path)
        print_success(f"Created folder: {export_folder_path}")

for article in articles:
    slug = article['slug']
    print(f"Exporting {slug}")

    # replace spaces with underscores in file names
    filename = f"{export_folder_path}{slug.replace(' ','_').replace('/','.')}.json"
    # replace umlaute
    filename = filename.lower().replace("ä","ae").replace("ü","ue").replace("ö","oe")
        # override or create output file
    with open(filename,"w",encoding="utf-8") as file:
        file.write(json.dumps(article))

        print_success(f"\t✅ Created or changed file {file.name}\n")
# Out:
# Exporting App-Wiki-Articles/de/Fokus-halten
# 	✅ Created or changed file ./converted/app-wiki-articles.de.fokus-halten.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.json
#
# Exporting App-Wiki-Articles/de/Lernraum-und-Lernumgebung
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernraum-und-lernumgebung.json
#
# Exporting App-Wiki-Articles/de/Lerntyp-Test-Hinweise
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lerntyp-test-hinweise.json
#
# Exporting App-Wiki-Articles/de/Lerntypen
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lerntypen.json
#
# Exporting App-Wiki-Articles/de/Prüfungsangst
# 	✅ Created or changed file ./converted/app-wiki-articles.de.pruefungsangst.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Aktives-Lesen
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.aktives-lesen.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Forschendes-Lernen
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.forschendes-lernen.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Fragen-Stellen
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.fragen-stellen.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Gamification
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.gamification.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Gedächtnispalast
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.gedaechtnispalast.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/In-Gruppen-Lernen
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.in-gruppen-lernen.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Lernen-durch-Lehren
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.lernen-durch-lehren.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Lernmethoden-Anwenden
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.lernmethoden-anwenden.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Memory-Methode
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.memory-methode.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Methoden-des-Aktiven-Lesens
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.methoden-des-aktiven-lesens.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Mnemotechniken
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.mnemotechniken.json
#
# Exporting App-Wiki-Articles/de/Lernmethoden/Modell-lernen
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lernmethoden.modell-lernen.json
#
# Exporting App-Wiki-Articles/de/Lerntypen/Auditiver-Lerntyp
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lerntypen.auditiver-lerntyp.json
#
# Exporting App-Wiki-Articles/de/Lerntypen/Kinästhetischer-Lerntyp
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lerntypen.kinaesthetischer-lerntyp.json
#
# Exporting App-Wiki-Articles/de/Lerntypen/Lesender-Lerntyp
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lerntypen.lesender-lerntyp.json
#
# Exporting App-Wiki-Articles/de/Lerntypen/Visueller-Lerntyp
# 	✅ Created or changed file ./converted/app-wiki-articles.de.lerntypen.visueller-lerntyp.json
#
# Exporting App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Emotionale-Ebene
# 	✅ Created or changed file ./converted/app-wiki-articles.de.pruefungsangst.pruefungsangst-emotionale-ebene.json
#
# Exporting App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Kognitive-Ebene
# 	✅ Created or changed file ./converted/app-wiki-articles.de.pruefungsangst.pruefungsangst-kognitive-ebene.json
#
# Exporting App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Körperliche-Ebene
# 	✅ Created or changed file ./converted/app-wiki-articles.de.pruefungsangst.pruefungsangst-koerperliche-ebene.json
#
# Exporting App-Wiki-Articles/de/Prüfungsangst/Prüfungsangst-Verhaltensebene
# 	✅ Created or changed file ./converted/app-wiki-articles.de.pruefungsangst.pruefungsangst-verhaltensebene.json
#
# Exporting App-Wiki-Articles/en/Exam-Anxiety
# 	✅ Created or changed file ./converted/app-wiki-articles.en.exam-anxiety.json
#
# Exporting App-Wiki-Articles/en/Focus
# 	✅ Created or changed file ./converted/app-wiki-articles.en.focus.json
#
# Exporting App-Wiki-Articles/en/Mental-Health
# 	✅ Created or changed file ./converted/app-wiki-articles.en.mental-health.json
#
# Exporting App-Wiki-Articles/en/Physical-Health
# 	✅ Created or changed file ./converted/app-wiki-articles.en.physical-health.json
#
# Exporting App-Wiki-Articles/en/Resilience
# 	✅ Created or changed file ./converted/app-wiki-articles.en.resilience.json
#
# Exporting App-Wiki-Articles/en/Sleep
# 	✅ Created or changed file ./converted/app-wiki-articles.en.sleep.json
#
# Exporting App-Wiki-Articles/en/Stress-Management
# 	✅ Created or changed file ./converted/app-wiki-articles.en.stress-management.json
#
# Exporting App-Wiki-Articles/en/Time-Management
# 	✅ Created or changed file ./converted/app-wiki-articles.en.time-management.json
